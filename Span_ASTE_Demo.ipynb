# %% [markdown]
# <a href="https://colab.research.google.com/github/jsvan/CommonSents/blob/master/Span_ASTE_Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/chiayewken/Span-ASTE.git
# !cd Span-ASTE && git checkout 074106b

# %%
# !cd Span-ASTE && bash setup.sh
# Out:
# ...
#      |████████████████████████████████| 1.4 MB 35.0 MB/s
# ...
#      |████████████████████████████████| 14.5 MB 50.0 MB/s
# ...
#      |████████████████████████████████| 8.6 MB 43.8 MB/s
# ...
#      |████████████████████████████████| 7.1 MB 63.4 MB/s
# ...
#      |████████████████████████████████| 776.7 MB 4.4 kB/s
# ...
#      |████████████████████████████████| 12.7 MB 72.4 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 43.0 MB/s
# ...
#      |████████████████████████████████| 106 kB 68.3 MB/s
# ...
#      |████████████████████████████████| 64 kB 3.4 MB/s
# ...
#      |████████████████████████████████| 56 kB 5.8 MB/s
# ...
#      |████████████████████████████████| 124 kB 67.2 MB/s
# ...
#      |████████████████████████████████| 259 kB 78.0 MB/s
# ...
#      |████████████████████████████████| 131 kB 62.0 MB/s
# ...
#      |████████████████████████████████| 138 kB 68.7 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 70.5 MB/s
# ...
#      |████████████████████████████████| 895 kB 76.6 MB/s
# ...

# %%
# !cd Span-ASTE && bash aste/main.sh 0
# Out:
# Streaming output truncated to the last 5000 lines.
# {'pred': '(Strong) [build] though which really adds to its durability .'}
# {'tp': {'Strong-build (POS)'}}
# {'fp': set()}
# {'fn': {'Strong-durability (POS)'}}
# ################################################################################
# {
#   "num_sentences": 328,
#   "num_pred": 535,
#   "num_gold": 543,
#   "num_correct": 330,
#   "num_start_correct": 407,
#   "num_start_end_correct": 394,
#   "num_opinion_correct": 564,
#   "num_target_correct": 598,
#   "num_span_overlap": 433,
#   "precision": 0.6168,
#   "recall": 0.6077,
#   "f_score": 0.612
# }
# {
#   "label": "OPINION",
#   "p": 0.8142,
#   "r": 0.8692,
#   "f": 0.8408
# }
# {
#   "label": "TARGET",
#   "p": 0.8191,
#   "r": 0.8898,
#   "f": 0.853
# }
#
#  What is the upper bound for RE from predicted O & T?
# {'recall': 0.7956}
# toal num of entity:  543
# total num of prediction:  535
#     name  ...    duration
# 0  14lap  ...  999.525553
#
# ...
